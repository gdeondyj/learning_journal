# %%
import pandas as pd
import numpy as np

# %%
covid19 = pd.read_csv('covid_19_indonesia_time_series_all.csv')

# %%
covid = pd.DataFrame(covid19)

# %%
covid.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            2             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               41  ... -6.204699                  0.18
# 1               41  ... -6.204699                  0.18
# ...

# %% [markdown]
# # Measure of Central Tendecy

# %%
print(covid['Total Deaths'].mean())
# Out:
# 2648.289351532699

# %%
print(covid['Total Deaths'].median())
# Out:
# 283.0

# %%
print(covid['Total Deaths'].mode())
# Out:
# 0    1
# dtype: int64

# %%
print(covid['Total Deaths'].mode()[0])
# Out:
# 1

# %% [markdown]
# # Measure of Variance

# %%
#standard deviation
covid.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 21754  12/2/2021             ID-SA    Sulawesi Utara          2           0
# 21755  12/2/2021             ID-SB    Sumatera Barat          4           0
# 21756  12/2/2021             ID-SS  Sumatera Selatan          4           0
# 21757  12/2/2021             ID-SU    Sumatera Utara          4           0
# ...

# %%
covid.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 21754  12/2/2021             ID-SA    Sulawesi Utara          2           0
# 21755  12/2/2021             ID-SB    Sumatera Barat          4           0
# 21756  12/2/2021             ID-SS  Sumatera Selatan          4           0
# 21757  12/2/2021             ID-SU    Sumatera Utara          4           0
# ...
